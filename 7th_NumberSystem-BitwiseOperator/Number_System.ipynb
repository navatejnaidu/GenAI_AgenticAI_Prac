# %%
25
# Out:
# 25

# %%
bin(25)
# Out:
# '0b11001'

# %%
int(0b11001)
# Out:
# 25

# %%
oct(25)
# Out:
# '0o31'

# %%
int(0o31)
# Out:
# 25

# %%
hex(16)
# Out:
# '0x10'

# %%
int(0x10)
# Out:
# 16

# %%
int(0x9)
# Out:
# 9

# %%
hex(25)
# Out:
# '0x19'

# %%
int(0x19)
# Out:
# 25

# %%
~12
# Out:
# -13

# %%
~35
# Out:
# -36

# %%
~18
# Out:
# -19

# %%
12 & 13
# Out:
# 12

# %%
12 | 13
# Out:
# 13

# %%
12 ^ 13
# Out:
# 1

# %%
12 << 2
# Out:
# 48

# %%
12 << 1
# Out:
# 24

# %%
12>>1
# Out:
# 6

# %%
12>>2
# Out:
# 3
