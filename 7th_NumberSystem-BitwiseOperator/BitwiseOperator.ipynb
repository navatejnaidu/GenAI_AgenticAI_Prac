# %%
oct(25)
# Out:
# '0o31'

# %%
int(0o31)
# Out:
# 25

# %%
hex(10)
# Out:
# '0xa'

# %%
hex(11)
# Out:
# '0xb'

# %%
hex(15)
# Out:
# '0xf'

# %%
hex(16)
# Out:
# '0x10'

# %%
int(0x10)
# Out:
# 16

# %%
12 & 13
# Out:
# 12

# %%
12 | 13
# Out:
# 13

# %%
bin(35)
# Out:
# '0b100011'

# %%
bin(40)
# Out:
# '0b101000'

# %%
35 ^ 40
# Out:
# 11

# %%
12 << 2
# Out:
# 48

# %%
12 << 1
# Out:
# 24

# %%
12>>2
# Out:
# 3

# %%
~12
# Out:
# -13

# %%
~34
# Out:
# -35

# %%
import math

# %%
x = math.sqrt(25) 
x
# Out:
# 5.0

# %%
import math as m 
m.sqrt(25)
# Out:
# 5.0

# %%
m.floor(4.5)
# Out:
# 4

# %%
m.ceil(4.5)
# Out:
# 5

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.e
# Out:
# 2.718281828459045

# %%
pi = 3.14
pi
# Out:
# 3.14

# %%
pi = 4.15
pi
# Out:
# 4.15

# %%
from math import sqrt, pow 

print(math.sqrt(35))

print(math.pow(2,3))
# Out:
# 5.916079783099616
# 8.0
# 2

# %%
from math import * 

print(math.sqrt(35))
print(math.pow(2,3)) 
print(math.floor(2.3))
print(math.ceil(2.3))
# Out:
# 5.916079783099616
# 8.0
# 2
# 3
