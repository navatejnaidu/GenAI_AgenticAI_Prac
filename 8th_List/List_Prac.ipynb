# %% [markdown]
# # List Practicals

# %%
l = []
l
# Out:
# []

# %%
type(l)
# Out:
# list

# %%
len(l)
# Out:
# 0

# %%
l.append(10)
l
# Out:
# [10]

# %%
len(l)
# Out:
# 1

# %%
l
# Out:
# [10]

# %%
l.append(20)
l.append(30)
l.append(40)
l.append(50)
l
# Out:
# [10, 20, 30, 40, 50]

# %%
len(l)
# Out:
# 5

# %%
l
# Out:
# [10, 20, 30, 40, 50]

# %%
l.append(10) 
l
# Out:
# [10, 20, 30, 40, 50, 10]

# %%
l1 = [10, 3.5, True, 1+2j, 'welcome'] 
l1
# Out:
# [10, 3.5, True, (1+2j), 'welcome']

# %%
print(l)
print(l1)
# Out:
# [10, 20, 30, 40, 50, 10]
# [10, 3.5, True, (1+2j), 'welcome', [1, 2, 3]]

# %%
l
# Out:
# [10, 20, 30, 40, 50, 10]

# %%
l3 = l.copy()
l3
# Out:
# [10, 20, 30, 40, 50, 10]

# %%
print(l)
print(l1)
print(l3)
# Out:
# [10, 20, 30, 40, 50, 10]
# [10, 3.5, True, (1+2j), 'welcome']
# [10, 20, 30, 40, 50, 10]

# %%
l == l3
# Out:
# True

# %%
len(l) == len(l3)
# Out:
# True

# %%
id(l) == id(l3)
# Out:
# False

# %%
id(l) != id(l3)
# Out:
# True

# %%
print(id(l))
print(id(l3))
# Out:
# 2791468492672
# 2791475459520

# %%
print(l)
print(l1)
print(l3)
# Out:
# [10, 20, 30, 40, 50, 10]
# [10, 3.5, True, (1+2j), 'welcome']
# [10, 20, 30, 40, 50, 10]

# %%
l3.clear()

# %%
print(l)
print(l1)
print(l3)
# Out:
# [10, 20, 30, 40, 50, 10]
# [10, 3.5, True, (1+2j), 'welcome']
# []

# %%
del l3

# %%
print(l)
print(l1)
# Out:
# [10, 20, 30, 40, 50, 10]
# [10, 3.5, True, (1+2j), 'welcome']

# %%
l
# Out:
# [10, 20, 30, 40, 50, 10]

# %%
l.count(30)
# Out:
# 1

# %%
l.count(10)
# Out:
# 2

# %%
l
# Out:
# [10, 20, 30, 40, 50, 10]

# %%
print(l)
print(l1)
# Out:
# [10, 20, 30, 40, 50, 10]
# [10, 3.5, True, (1+2j), 'welcome']

# %%
l.extend(l1) 
l
# Out:
# [10,
#  20,
#  30,
#  40,
#  50,
#  10,
#  10,
#  3.5,
#  True,
#  (1+2j),
#  'welcome',
#  10,
#  3.5,
#  True,
#  (1+2j),
#  'welcome']

# %%
print(len(l))
print(len(l1))
# Out:
# 16
# 5

# %%
a1 = [1,2,3]
b1 = [4,5,6]

# %%
a1.extend(b1)
a1
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
print(a1)
print(b1)
# Out:
# [1, 2, 3, 4, 5, 6]
# [4, 5, 6]

# %%
print(l)
print(l1)
# Out:
# [10, 20, 30, 40, 50, 10, 10, 3.5, True, (1+2j), 'welcome', 10, 3.5, True, (1+2j), 'welcome']
# [10, 3.5, True, (1+2j), 'welcome']

# %%
l.index(20)
# Out:
# 1

# %%
l1
# Out:
# [10, 3.5, True, (1+2j), 'welcome']

# %%
l1.index(1+2j)
# Out:
# 3

# %%
l1.index('welcome')
# Out:
# 4

# %%
l1
# Out:
# [10, 3.5, True, (1+2j), 'welcome']

# %%
l1[:]
# Out:
# [10, 3.5, True, (1+2j), 'welcome']

# %%
l1
# Out:
# [10, 3.5, True, (1+2j), 'welcome']

# %%
l1[4]
# Out:
# 'welcome'

# %%
l1
# Out:
# [10, 3.5, True, (1+2j), 'welcome']

# %%
l1[:3]
# Out:
# [10, 3.5, True]

# %%
l1
# Out:
# [10, 3.5, True, (1+2j), 'welcome']

# %%
l1[3:]
# Out:
# [(1+2j), 'welcome']

# %%
l1
# Out:
# [10, 3.5, True, (1+2j), 'welcome']

# %%
l1[0:5:2]
# Out:
# [10, True, 'welcome']

# %%
l1
# Out:
# [10, 3.5, True, (1+2j), 'welcome']

# %%
l1[-3]
# Out:
# True

# %%
l1[-3:]
# Out:
# [True, (1+2j), 'welcome']

# %%
l1
# Out:
# [10, 3.5, True, (1+2j), 'welcome']

# %%
l1[::-1]
# Out:
# ['welcome', (1+2j), True, 3.5, 10]

# %%
l1
# Out:
# [10, 3.5, True, (1+2j), 'welcome']

# %%
l1[::-2]
# Out:
# ['welcome', True, 10]

# %%
l1
# Out:
# [10, 3.5, True, (1+2j), 'welcome']

# %%
l1[4]
# Out:
# 'welcome'

# %%
l1
# Out:
# [10, 3.5, True, (1+2j), 'welcome']

# %%
l1[0]
# Out:
# 10

# %%
l1[0] = 100

# %%
l1
# Out:
# [100, 3.5, True, (1+2j), 'welcome']
