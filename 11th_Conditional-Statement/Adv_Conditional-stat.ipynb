# %%
x = 4

r = x % 2 

if r == 0:   
    print('Even number')
# Out:
# Even number

# %%
x = 5
r = x % 2 

if r == 0:    
    print('Even number')

# %%
x = 4
r = x % 2 

if r == 0:    
    print('Even number')
    
if r == 1:
    print('odd number')

if r == 2:
    print('even')
# Out:
# Even number

# %%
x = 4
r = x % 2 

if r == 0:    
    print('Even number')
    
else:
    print('odd number')
# Out:
# Even number

# %%
x = 3
r = x % 2

if r == 0:
    print('Even number')
    if x>5:
        print('greater number')
  
else:
    print('Odd Number')
# Out:
# Odd Number

# %%
x = 6
r = x % 2

if r == 0:
    print('Even number')
    if x>5:
        print('greater number')
  
else:
    print('Odd Number')

# %%
x = 4
r = x % 2

if r == 0:
    print('Even number')
    
    if x>5:
        print('greater number')
  
else:
    print('Odd Number')
# Out:
# Even number

# %%
x = 4
r = x % 2

if r == 0:
    print('Even number')
    
    if x>5:
        print('greater number')
    else:
        print('lesser number')
  
else:
    print('Odd Number')
# Out:
# Even number
# lesser number

# %% [markdown]
# # if -- elif -- else

# %%
x = 1

if x == 1:
    print('one')
if x == 2:
    print('Two')
if x == 3:
    print('Three')
if x == 4:
    print('four')

# %%
x = 4

if x == 1:
    print('one')

elif x== 2:
    print('Two')
elif x == 3:
    print('Three')
elif x == 4:
    print('four')
# Out:
# four

# %%
x = 1

if x == 1:
    print('one')

elif x== 2:
    print('Two')
elif x == 3:
    print('Three')
elif x == 4:
    print('four')

else:
    print('number not found')
# Out:
# one

# %%
age = 19
if age > 18: print("Eligible to Vote.")
# Out:
# Eligible to Vote.
