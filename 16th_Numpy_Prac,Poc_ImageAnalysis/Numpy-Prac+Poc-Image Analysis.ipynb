# %%
import numpy as np

# %%
np.ones([2,3])
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.]])

# %%
np.ones(5, dtype=int)
# Out:
# array([1, 1, 1, 1, 1])

# %%
np.random.rand(3)
# Out:
# array([0.35702949, 0.17441039, 0.15198763])

# %%
np.random.rand(3,4)
# Out:
# array([[0.95228278, 0.00392873, 0.37571474, 0.39469706],
#        [0.2581189 , 0.20605321, 0.49305968, 0.39601976],
#        [0.30321569, 0.08807858, 0.63309651, 0.42316496]])

# %%
np.random.randint(3)
# Out:
# 2

# %%
np.random.randint(5,10)
# Out:
# 9

# %%
np.random.randint(2, 10, 4)
# Out:
# array([5, 5, 9, 2], dtype=int32)

# %%
arr1 = np.random.randint(1,9,(4,5))
print(arr1)
# Out:
# [[1 7 8 3 3]
#  [7 5 7 2 6]
#  [7 6 1 7 4]
#  [8 2 7 8 4]]

# %%
arr1[0]
# Out:
# array([1, 7, 8, 3, 3], dtype=int32)

# %%
arr1[3]
# Out:
# array([8, 2, 7, 8, 4], dtype=int32)

# %%
arr1.shape
# Out:
# (4, 5)

# %%
arr1
# Out:
# array([[1, 7, 8, 3, 3],
#        [7, 5, 7, 2, 6],
#        [7, 6, 1, 7, 4],
#        [8, 2, 7, 8, 4]], dtype=int32)

# %%
arr1[1,4]
# Out:
# np.int32(6)

# %%
print(arr1[1,4])
# Out:
# 6

# %%
arr1
# Out:
# array([[1, 7, 8, 3, 3],
#        [7, 5, 7, 2, 6],
#        [7, 6, 1, 7, 4],
#        [8, 2, 7, 8, 4]], dtype=int32)

# %%
arr1[-3,3]
# Out:
# np.int32(2)

# %%
arr1
# Out:
# array([[1, 7, 8, 3, 3],
#        [7, 5, 7, 2, 6],
#        [7, 6, 1, 7, 4],
#        [8, 2, 7, 8, 4]], dtype=int32)

# %%
arr1[:]
# Out:
# array([[1, 7, 8, 3, 3],
#        [7, 5, 7, 2, 6],
#        [7, 6, 1, 7, 4],
#        [8, 2, 7, 8, 4]], dtype=int32)

# %%
arr1[1:4]
# Out:
# array([[7, 5, 7, 2, 6],
#        [7, 6, 1, 7, 4],
#        [8, 2, 7, 8, 4]], dtype=int32)

# %%
arr1[::-1]
# Out:
# array([[8, 2, 7, 8, 4],
#        [7, 6, 1, 7, 4],
#        [7, 5, 7, 2, 6],
#        [1, 7, 8, 3, 3]], dtype=int32)

# %%
arr1[::-3]
# Out:
# array([[8, 2, 7, 8, 4],
#        [1, 7, 8, 3, 3]], dtype=int32)

# %%
arr1[:40]
# Out:
# array([[1, 7, 8, 3, 3],
#        [7, 5, 7, 2, 6],
#        [7, 6, 1, 7, 4],
#        [8, 2, 7, 8, 4]], dtype=int32)

# %%
arr1[:10000]
# Out:
# array([[1, 7, 8, 3, 3],
#        [7, 5, 7, 2, 6],
#        [7, 6, 1, 7, 4],
#        [8, 2, 7, 8, 4]], dtype=int32)

# %%
arr1[2:]
# Out:
# array([[7, 6, 1, 7, 4],
#        [8, 2, 7, 8, 4]], dtype=int32)

# %%
arr1[10:]
# Out:
# array([], shape=(0, 5), dtype=int32)

# %%
arr1[:, 0]
# Out:
# array([1, 7, 7, 8], dtype=int32)

# %%
arr1[:, 2]
# Out:
# array([8, 7, 1, 7], dtype=int32)

# %%
arr1[:, -1]
# Out:
# array([3, 6, 4, 4], dtype=int32)

# %%
arr1[1:3 , 1:3]
# Out:
# array([[5, 7],
#        [6, 1]], dtype=int32)

# %%
arr1
# Out:
# array([[1, 7, 8, 3, 3],
#        [7, 5, 7, 2, 6],
#        [7, 6, 1, 7, 4],
#        [8, 2, 7, 8, 4]], dtype=int32)

# %%
arr1[0:3, 2:5]
# Out:
# array([[8, 3, 3],
#        [7, 2, 6],
#        [1, 7, 4]], dtype=int32)

# %%
arr1
# Out:
# array([[1, 7, 8, 3, 3],
#        [7, 5, 7, 2, 6],
#        [7, 6, 1, 7, 4],
#        [8, 2, 7, 8, 4]], dtype=int32)

# %%
arr1[1:4]
# Out:
# array([[7, 5, 7, 2, 6],
#        [7, 6, 1, 7, 4],
#        [8, 2, 7, 8, 4]], dtype=int32)

# %%
arr1[2:3]
# Out:
# array([[7, 6, 1, 7, 4]], dtype=int32)

# %%
arr1[arr1<=5]
# Out:
# array([1, 3, 3, 5, 2, 1, 4, 2, 4], dtype=int32)

# %%
len(arr1[arr1<5])
# Out:
# 8

# %%
arr1[arr1!=5]
# Out:
# array([1, 7, 8, 3, 3, 7, 7, 2, 6, 7, 6, 1, 7, 4, 8, 2, 7, 8, 4],
#       dtype=int32)

# %%
print(arr1[arr1!=5])
# Out:
# [1 7 8 3 3 7 7 2 6 7 6 1 7 4 8 2 7 8 4]

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from PIL import Image

# %%
image = Image.open(r'D:\GenAI_AgenticAI_notes\1st - Github createion, Demo, Software Installation\python.png')

# %%
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1068x670>

# %%
type(image)
# Out:
# PIL.PngImagePlugin.PngImageFile

# %%
img_arr = np.asarray(image)

# %%
img_arr
# Out:
# array([[[232, 237, 244, 255],
#         [232, 237, 244, 255],
#         [232, 237, 244, 255],
#         ...,
#         [232, 237, 244, 255],
#         [232, 237, 244, 255],
#         [232, 237, 244, 255]],
#
#        [[232, 237, 244, 255],
#         [232, 237, 244, 255],
#         [232, 237, 244, 255],
#         ...,
#         [232, 237, 244, 255],
#         [232, 237, 244, 255],
#         [232, 237, 244, 255]],
#
#        [[232, 237, 244, 255],
#         [232, 237, 244, 255],
#         [232, 237, 244, 255],
#         ...,
#         [232, 237, 244, 255],
#         [232, 237, 244, 255],
#         [232, 237, 244, 255]],
#
#        ...,
#
#        [[232, 237, 244, 255],
#         [232, 237, 244, 255],
#         [232, 237, 244, 255],
#         ...,
#         [232, 237, 244, 255],
#         [232, 237, 244, 255],
#         [232, 237, 244, 255]],
#
#        [[232, 237, 244, 255],
#         [232, 237, 244, 255],
#         [232, 237, 244, 255],
#         ...,
#         [232, 237, 244, 255],
# ...

# %%
plt.imshow(img_arr)

# %%
plt.show()

# %%
img_arr.shape
# Out:
# (670, 1068, 4)

# %%
import numpy as np

# %%
text = "Generative AI is the future"

# %%
arr = np.array(text.split())
print(arr
     )
# Out:
# ['Generative' 'AI' 'is' 'the' 'future']

# %%
print(type(arr))
# Out:
# <class 'numpy.ndarray'>

# %%
text1 = "Python"
arr = np.array(text1.split())

# %%
print(arr)
# Out:
# ['Python']
