# %%
5
# Out:
# 5

# %%
6
# Out:
# 6

# %%
5 + 3
# Out:
# 8

# %%
11 + 5
# Out:
# 16

# %%
7 - 5
# Out:
# 2

# %%
10 * 3
# Out:
# 30

# %%
50 / 5
# Out:
# 10.0

# %%
10 // 2
# Out:
# 5

# %%
4 * 2
# Out:
# 8

# %%
3 ** 2
# Out:
# 9

# %%
25 % 5
# Out:
# 0

# %%
Okay
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 Okay
#
# NameError: name 'Okay' is not defined

# %%
'python'
# Out:
# 'python'

# %%
" come on lets learn python in vs code '
# Out:
#   Cell In[23], line 1
#     " come on lets learn python in vs code '
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
"come on lets learn python in vs code"
# Out:
# 'come on lets learn python in vs code'

# %% [markdown]
# # VARIABLE DECLARATION

# %%
A = 100
A
# Out:
# 100

# %%
100 = A
# Out:
#   Cell In[4], line 1
#     100 = A
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
1v = 777
1v
# Out:
#   Cell In[6], line 1
#     1v = 777
#     ^
# SyntaxError: invalid decimal literal

# %%
x1 = 24
x1
# Out:
# 24

# %%
nit = 24
NIT
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 nit = 24
# ----> 2 NIT
#
# NameError: name 'NIT' is not defined

# %%
nit = 24
nit
# Out:
# 24

# %%
nit@ = 300
nit@
# Out:
#   Cell In[10], line 1
#     nit@ = 300
#          ^
# SyntaxError: invalid syntax

# %%
nit! = 45
# Out:
#   Cell In[11], line 1
#     nit! = 45
#        ^
# SyntaxError: invalid syntax

# %%
number_ = 99
number_
# Out:
# 99

# %%
_number = 100
_number
# Out:
# 100

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
def = 100
def
# Out:
#   Cell In[16], line 1
#     def = 100
#         ^
# SyntaxError: invalid syntax

# %%
if = 67
# Out:
#   Cell In[18], line 1
#     if = 67
#        ^
# SyntaxError: invalid syntax

# %%
IF = 86
IF
# Out:
# 86

# %%
len(keyword.kwlist)
# Out:
# 35

# %%
del = 39
del
# Out:
#   Cell In[22], line 1
#     del = 39
#         ^
# SyntaxError: invalid syntax

# %%
x = 57 
x
# Out:
# 57

# %%
x = 20
x
# Out:
# 20

# %%
x1 = 57
x1
# Out:
# 57

# %%
x1
# Out:
# 57

# %%
x
# Out:
# 20

# %%
10 - 3
10 * 3
10 + 3
10 / 3
# Out:
# 3.3333333333333335

# %%
print(10 - 3)
print(10 * 3)
print(10 + 3)
print(10 / 3)
# Out:
# 7
# 30
# 13
# 3.3333333333333335
