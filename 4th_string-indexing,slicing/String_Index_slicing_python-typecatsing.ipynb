# %% [markdown]
# # String Index Prac

# %%
s1= 'WelcometoGit'
s1
# Out:
# 'WelcometoGit'

# %%
s1[:]
# Out:
# 'WelcometoGit'

# %%
s1[6:9] # Python prints the element from 7th index to 9-1 index
# Out:
# 'eto'

# %%
s1[:9]
# Out:
# 'Welcometo'

# %%
s1
# Out:
# 'WelcometoGit'

# %%
s1[6:]
# Out:
# 'etoGit'

# %% [markdown]
# # Advanced slicing

# %%
s1
# Out:
# 'WelcometoGit'

# %%
s1[::3]
# Out:
# 'WceG'

# %%
s1
# Out:
# 'WelcometoGit'

# %%
s1[0:10:5]
# Out:
# 'Wm'

# %%
s1
# Out:
# 'WelcometoGit'

# %%
s1[::-1]
# Out:
# 'tiGotemocleW'

# %%
s1
# Out:
# 'WelcometoGit'

# %%
s1[::-5]
# Out:
# 'tee'

# %% [markdown]
# # python type casting
#
# # convert from all other dataype to integer

# %%
# converting or type casting from one datatype to another 
int(11.67)  # cast
# Out:
# 11

# %%
int(False)
# Out:
# 0

# %%
True + True + False
# Out:
# 2

# %%
int(True)
# Out:
# 1

# %%
int(89.3,192.5) #For int type casting user can only pass one argument
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[149], line 1
# ----> 1 int(89.3,192.5) #For int type casting user can only pass one argument
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
int(1+6j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 int(1+6j)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
int('28') # number string
# Out:
# 28

# %%
int('two')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 int('two')
#
# ValueError: invalid literal for int() with base 10: 'two'

# %% [markdown]
# # Type cast All other Datatype to float

# %%
float(20)
# Out:
# 20.0

# %%
float(True)
# Out:
# 1.0

# %%
float(False)
# Out:
# 0.0

# %%
float(35+26j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 float(35+26j)
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %%
float('10')
# Out:
# 10.0

# %%
float('ten')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 float('ten')
#
# ValueError: could not convert string to float: 'ten'

# %%
bool(37) #int to bool
# Out:
# True

# %%
bool(1.45) #float to bool
# Out:
# True

# %%
bool( )
# Out:
# False

# %%
bool(1+2j)
# Out:
# True

# %%
bool('670')
# Out:
# True

# %%
bool('ten')
# Out:
# True

# %%
bool(0)
# Out:
# False

# %% [markdown]
# # All other Datatype to complex

# %%
complex(8000)
# Out:
# (8000+0j)

# %%
complex(50, 29)
# Out:
# (50+29j)

# %%
complex(10,20,30)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[93], line 1
# ----> 1 complex(10,20,30)
#
# TypeError: complex() takes at most 2 arguments (3 given)

# %%
complex(1.3, 2.4)
# Out:
# (1.3+2.4j)

# %%
complex(True, False)
# Out:
# (1+0j)

# %%
complex('99')
# Out:
# (99+0j)

# %%
complex('53', '50')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[97], line 1
# ----> 1 complex('53', '50')
#
# TypeError: complex() can't take second arg if first is a string

# %%
complex('10', 20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[98], line 1
# ----> 1 complex('10', 20)
#
# TypeError: complex() can't take second arg if first is a string

# %%
complex(10, '20')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[99], line 1
# ----> 1 complex(10, '20')
#
# TypeError: complex() second arg can't be a string

# %% [markdown]
# # All other Datatype to string

# %%
str(10)
# Out:
# '10'

# %%
str(4.4)
# Out:
# '4.4'

# %%
str(False)
# Out:
# 'False'

# %%
str(1+2j)
# Out:
# '(1+2j)'
