# %% [markdown]
# # Python Data Type
# - Int   (Integer)
# - Float (Decimal)
# - Bool (Boolean) True or False
# - Complex (Complex Numbers)
# - String (To handle alphabets)

# %% [markdown]
# # Float

# %%
f = 14.28 
f
# Out:
# 14.28

# %%
type(f)
# Out:
# float

# %%
1f = 24.53
1f
# Out:
#   Cell In[4], line 1
#     1f = 24.53
#     ^
# SyntaxError: invalid decimal literal

# %%
f1 = 67.67
f1
# Out:
# 67.67

# %%
type(f1)
# Out:
# float

# %% [markdown]
# # Boolean

# %%
a = true
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 a = true
#       2 a
#
# NameError: name 'true' is not defined

# %%
b = True
b
# Out:
# True

# %%
a1 = False
a1
# Out:
# False

# %%
a2 = None
a2

# %%
True + True
# Out:
# 2

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
True + False
# Out:
# 1

# %%
True * False
# Out:
# 0

# %%
False * False
# Out:
# 0

# %%
False / True
# Out:
# 0.0

# %%
False // True
# Out:
# 0

# %%
True / False # run time error
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 True / False # run time error
#
# ZeroDivisionError: division by zero

# %% [markdown]
# # Complex Datatype

# %%
c = 10 + 20j
c
# Out:
# (10+20j)

# %%
type(c)
# Out:
# complex

# %%
c.real
# Out:
# 10.0

# %%
c.imag
# Out:
# 20.0

# %%
d = 30+40j

# %%
print(c)
print(d)
# Out:
# (10+20j)
# (30+40j)

# %%
e = 2.3 + 3.4j
e
# Out:
# (2.3+3.4j)

# %%
e.real
# Out:
# 2.3

# %%
print(c)
print(d)
# Out:
# (10+20j)
# (30+40j)

# %%
c + d
# Out:
# (40+60j)

# %% [markdown]
# # String

# %%
s = 'welcom to genai and agentic ai batch'
s
# Out:
# 'welcom to genai and agentic ai batch'

# %%
s2= '''welcom to genai and agentic ai batch'''
s2
# Out:
# 'welcom to genai and agentic ai batch'

# %%
s3 = ''' welcom 
            to 
        gen ai 
            agentic ai '''
s3
# Out:
# ' welcom \n            to \n        gen ai \n            agentic ai '

# %%
s = 'welcome'
s
# Out:
# 'welcome'

# %%
s[3] #forward index
# Out:
# 'c'

# %%
s[6]
# Out:
# 'e'

# %%
s
# Out:
# 'welcome'

# %%
s[7]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 s[7]
#
# IndexError: string index out of range

# %%
s
# Out:
# 'welcome'

# %%
s[10]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 s[10]
#
# IndexError: string index out of range

# %%
s
# Out:
# 'welcome'

# %%
s[-4] # backward Index
# Out:
# 'c'

# %%
s
# Out:
# 'welcome'

# %%
s[-2]
# Out:
# 'm'

# %%
s[-7]
# Out:
# 'w'

# %%
s[-10]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 s[-10]
#
# IndexError: string index out of range

# %%
s
# Out:
# 'welcome'

# %%
s[:]
# Out:
# 'welcome'
