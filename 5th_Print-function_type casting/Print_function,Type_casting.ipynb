# %% [markdown]
# # Print Functions
#
# - mostly used for printing answers

# %%
print('Max it')
# Out:
# Max it

# %%
"max it technology"
# Out:
# 'max it technology'

# %%
s1 = 'max it technology'
s1
# Out:
# 'max it technology'

# %%
print("max it's""Technology") # \ has some special meaning to ignore the error
# Out:
# max it'sTechnology

# %%
print('max it\'s"Technology"') #\ has some special meaning to ignore the error
# Out:
# max it's"Technology"

# %%
print('max it',  'Technology')
# Out:
# max it Technology

# %%
print("max it',  'Technology")
# Out:
# max it',  'Technology

# %%
# print the nit 2 times 
'nit' + ' nit'
# Out:
# 'nit nit'

# %%
'nit'  ' nit'
# Out:
# 'nit nit'

# %%
#5 time print
5 * 'nit'
# Out:
# 'nitnitnitnitnit'

# %%
5*' nit' # soace between words
# Out:
# ' nit nit nit nit nit'

# %%
print(r'c:\nit') #raw string
# Out:
# c:\nit

# %%
a = 100
b = 60
c = a + b
c
# Out:
# 160

# %%
a = 100
b = 60
c =  a+b
print(c)
print(a)
print(b)
# Out:
# 160
# 100
# 60

# %%
a = 10
b = 20
a
b
# Out:
# 20

# %%
a = 100
b = 20
print(a)
print(b)
# Out:
# 100
# 20

# %%
print(100)
print(209)
print(100, 209)
print("Python")
print(100, 209, "Python")
# Out:
# 100
# 209
# 100 209
# Python
# 100 209 Python

# %%
num1 = 20
num2 = 30
num3 = num1 + num2
print(num3)
# Out:
# 50

# %%
num1 = 100
num2 = 200
add = num1 + num2
print('The sum of', num1, 'and', num2, 'is =', add)
# Out:
# The sum of 100 and 200 is = 300

# %%
name = 'Python'
age = 20
city = 'Sri Vijay Puram'
print('Hello My name is', name, 'I am', age, 'years old and I live in', city)
# Out:
# Hello My name is Python I am 20 years old and I live in Sri Vijay Puram

# %%
num1 = 100
num2 = 200
add = num1 + num2
print('The addition of {} and {} is = {}'.format(num1, num2, add))
# Out:
# The addition of 100 and 200 is = 300

# %%
name = 'Python'
age = 20
city = 'Sri Vijay Puram'
print('Hello My name is {} and, I am {} years old and I live in {}'.format(name, age, city))
# Out:
# Hello My name is Python and, I am 20 years old and I live in Sri Vijay Puram

# %%
num1 = 10
num2 = 20
num3 = 30
avg = (num1+num2+num3)
avg1 = round((num1+num2+num3)/3, 2)

print('The average of {} , {} and {} is = {}'.format(num1, num2, num3, avg1))
# Out:
# The average of 10 , 20 and 30 is = 20.0

# %%
round(avg, 2)
# Out:
# 60

# %%
num1 = 100
num2 = 200
add = num1 + num2
print(f'The addition of {num1} and {num2} is = {add}')
# Out:
# The addition of 100 and 200 is = 300

# %%
name = 'Python'
age = 20
city = 'Sri Vijay Puram'
print(f'Hello my name is {name} and, I am {age} years old and I live in {city}')
# Out:
# Hello my name is Python and, I am 20 years old and I live in Sri Vijay Puram

# %%
num1 = 100
num2 = 25
num3 = 333
avg = round((num1+num2+num3)/3, 2)
print(f'The average of {num1}, {num2}, and {num3} is = {avg}')
# Out:
# The average of 100, 25, and 333 is = 152.67

# %%
num1 = 10
num2 = 20
add = num1 + num2
print(f'The addition of {num1} and {num2} is = {add}')
print('The addition of {} and {} is = {}'.format(num1, num2, add))
print('The addition of', num1, 'and', num2, 'is =', add)
# Out:
# The addition of 10 and 20 is = 30
# The addition of 10 and 20 is = 30
# The addition of 10 and 20 is = 30

# %%
print('Hello')
print('Good morning')
# Out:
# Hello
# Good morning

# %%
print('Hello', end=' ')
print('World Good Day')
# Out:
# Hello World Good Day

# %%
print('Hello','Hi','How are you?',sep ='---->')
# Out:
# Hello---->Hi---->How are you?

# %%
print('Hello','Hi','How are you?',sep = '&')
# Out:
# Hello&Hi&How are you?

# %%
print('Hello','Hi','How are you?',sep='@')
# Out:
# Hello@Hi@How are you?

# %%
print('Hello','Hi','How are you?',sep = ' ')
# Out:
# Hello Hi How are you?

# %%
print(3,'.',sep = ' ')
# Out:
# 3 .

# %%
print(3,'.')
# Out:
# 3 .

# %%
print(1,2,end = ' ')
print(3,'.',sep = ' ')
# Out:
# 1 2 3 .
