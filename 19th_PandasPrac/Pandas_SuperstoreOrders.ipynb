# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.3.3'

# %%
store = pd.read_excel(r"C:\Users\polin\Desktop\GenAI_AgenticAI_Prac\Python Prac\19th_PandasPrac\Superstore_Orders_Supplies.xlsx")

# %%
store
# Out:
#      Order ID                                         Order Date  \
# 0    ORD-0001  Mon May 20 2024 05:30:00 GMT+0530 (India Stand...
# 1    ORD-0002  Mon Oct 14 2024 05:30:00 GMT+0530 (India Stand...
# 2    ORD-0003  Wed May 22 2024 05:30:00 GMT+0530 (India Stand...
# 3    ORD-0004  Tue Oct 01 2024 05:30:00 GMT+0530 (India Stand...
# 4    ORD-0005  Sat Feb 10 2024 05:30:00 GMT+0530 (India Stand...
# ..        ...                                                ...
# 395  ORD-0396  Sat Jul 06 2024 05:30:00 GMT+0530 (India Stand...
# 396  ORD-0397  Sun Apr 07 2024 05:30:00 GMT+0530 (India Stand...
# 397  ORD-0398  Tue Jan 23 2024 05:30:00 GMT+0530 (India Stand...
# 398  ORD-0399  Fri Nov 15 2024 05:30:00 GMT+0530 (India Stand...
# 399  ORD-0400  Wed Jul 03 2024 05:30:00 GMT+0530 (India Stand...
#
#     Customer Name  Product Name         Category   Region       State  \
# 0      John Smith        Laptop       Technology     East    Illinois
# ...

# %%
id(store)
# Out:
# 2261584764544

# %%
len(store)
# Out:
# 400

# %%
store.shape
# Out:
# (400, 11)

# %%
store.columns
# Out:
# Index(['Order ID', 'Order Date', 'Customer Name', 'Product Name', 'Category',
#        'Region', 'State', 'Quantity', 'Sales', 'Discount', 'Profit'],
#       dtype='object')

# %%
len(store.columns)
# Out:
# 11

# %%
store.isnull()
# Out:
#      Order ID  Order Date  Customer Name  Product Name  Category  Region  \
# 0       False       False          False         False     False   False
# 1       False       False          False         False     False   False
# 2       False       False          False         False     False   False
# 3       False       False          False         False     False   False
# 4       False       False          False         False     False   False
# ..        ...         ...            ...           ...       ...     ...
# 395     False       False          False         False     False   False
# 396     False       False          False         False     False   False
# 397     False       False          False         False     False   False
# 398     False       False          False         False     False   False
# 399     False       False          False         False     False   False
#
#      State  Quantity  Sales  Discount  Profit
# ...

# %%
store.isnull().sum()
# Out:
# Order ID         0
# Order Date       0
# Customer Name    0
# Product Name     0
# Category         0
# Region           0
# State            0
# Quantity         0
# Sales            0
# Discount         0
# Profit           0
# dtype: int64

# %%
store[:]
# Out:
#      Order ID                                         Order Date  \
# 0    ORD-0001  Mon May 20 2024 05:30:00 GMT+0530 (India Stand...
# 1    ORD-0002  Mon Oct 14 2024 05:30:00 GMT+0530 (India Stand...
# 2    ORD-0003  Wed May 22 2024 05:30:00 GMT+0530 (India Stand...
# 3    ORD-0004  Tue Oct 01 2024 05:30:00 GMT+0530 (India Stand...
# 4    ORD-0005  Sat Feb 10 2024 05:30:00 GMT+0530 (India Stand...
# ..        ...                                                ...
# 395  ORD-0396  Sat Jul 06 2024 05:30:00 GMT+0530 (India Stand...
# 396  ORD-0397  Sun Apr 07 2024 05:30:00 GMT+0530 (India Stand...
# 397  ORD-0398  Tue Jan 23 2024 05:30:00 GMT+0530 (India Stand...
# 398  ORD-0399  Fri Nov 15 2024 05:30:00 GMT+0530 (India Stand...
# 399  ORD-0400  Wed Jul 03 2024 05:30:00 GMT+0530 (India Stand...
#
#     Customer Name  Product Name         Category   Region       State  \
# 0      John Smith        Laptop       Technology     East    Illinois
# ...

# %%
store[0:10]
# Out:
#    Order ID                                         Order Date Customer Name  \
# 0  ORD-0001  Mon May 20 2024 05:30:00 GMT+0530 (India Stand...    John Smith
# 1  ORD-0002  Mon Oct 14 2024 05:30:00 GMT+0530 (India Stand...  James Wilson
# 2  ORD-0003  Wed May 22 2024 05:30:00 GMT+0530 (India Stand...  Robert Brown
# 3  ORD-0004  Tue Oct 01 2024 05:30:00 GMT+0530 (India Stand...   Linda Davis
# 4  ORD-0005  Sat Feb 10 2024 05:30:00 GMT+0530 (India Stand...   Linda Davis
# 5  ORD-0006  Thu Nov 21 2024 05:30:00 GMT+0530 (India Stand...  Mary Johnson
# 6  ORD-0007  Sat Apr 27 2024 05:30:00 GMT+0530 (India Stand...   Linda Davis
# 7  ORD-0008  Wed May 15 2024 05:30:00 GMT+0530 (India Stand...  James Wilson
# 8  ORD-0009  Thu Jan 25 2024 05:30:00 GMT+0530 (India Stand...  Mary Johnson
# 9  ORD-0010  Sat Jan 06 2024 05:30:00 GMT+0530 (India Stand...  James Wilson
#
#    Product Name         Category   Region       State  Quantity   Sales  \
# ...

# %%
store[0:20:5]
# Out:
#     Order ID                                         Order Date Customer Name  \
# 0   ORD-0001  Mon May 20 2024 05:30:00 GMT+0530 (India Stand...    John Smith
# 5   ORD-0006  Thu Nov 21 2024 05:30:00 GMT+0530 (India Stand...  Mary Johnson
# 10  ORD-0011  Mon Apr 01 2024 05:30:00 GMT+0530 (India Stand...  Robert Brown
# 15  ORD-0016  Thu Oct 03 2024 05:30:00 GMT+0530 (India Stand...  James Wilson
#
#    Product Name         Category Region     State  Quantity   Sales  Discount  \
# 0        Laptop       Technology   East  Illinois         1   850.0      0.05
# 5        Laptop       Technology   West   Florida        10  8500.0      0.05
# 10         Desk        Furniture   West     Texas         9  2700.0      0.20
# 15        Paper  Office Supplies  South     Texas         4    24.0      0.05
#
#      Profit
# 0    104.25
# 5   1594.90
# 10   606.48
# 15     5.45

# %%
store.head()
# Out:
#    Order ID                                         Order Date Customer Name  \
# 0  ORD-0001  Mon May 20 2024 05:30:00 GMT+0530 (India Stand...    John Smith
# 1  ORD-0002  Mon Oct 14 2024 05:30:00 GMT+0530 (India Stand...  James Wilson
# 2  ORD-0003  Wed May 22 2024 05:30:00 GMT+0530 (India Stand...  Robert Brown
# 3  ORD-0004  Tue Oct 01 2024 05:30:00 GMT+0530 (India Stand...   Linda Davis
# 4  ORD-0005  Sat Feb 10 2024 05:30:00 GMT+0530 (India Stand...   Linda Davis
#
#    Product Name         Category   Region       State  Quantity   Sales  \
# 0        Laptop       Technology     East    Illinois         1   850.0
# 1      Keyboard       Technology    South       Texas         1    45.0
# 2       Monitor       Technology     East  California         6  1650.0
# 3  Office Chair        Furniture     East    Illinois         8  1000.0
# 4      Notebook  Office Supplies  Central     Florida         5    42.5
#
#    Discount  Profit
# 0      0.05  104.25
# 1      0.05   10.15
# ...

# %%
store.head(3)
# Out:
#    Order ID                                         Order Date Customer Name  \
# 0  ORD-0001  Mon May 20 2024 05:30:00 GMT+0530 (India Stand...    John Smith
# 1  ORD-0002  Mon Oct 14 2024 05:30:00 GMT+0530 (India Stand...  James Wilson
# 2  ORD-0003  Wed May 22 2024 05:30:00 GMT+0530 (India Stand...  Robert Brown
#
#   Product Name    Category Region       State  Quantity   Sales  Discount  \
# 0       Laptop  Technology   East    Illinois         1   850.0      0.05
# 1     Keyboard  Technology  South       Texas         1    45.0      0.05
# 2      Monitor  Technology   East  California         6  1650.0      0.05
#
#    Profit
# 0  104.25
# 1   10.15
# 2  199.65

# %%
store.tail()
# Out:
#      Order ID                                         Order Date  \
# 395  ORD-0396  Sat Jul 06 2024 05:30:00 GMT+0530 (India Stand...
# 396  ORD-0397  Sun Apr 07 2024 05:30:00 GMT+0530 (India Stand...
# 397  ORD-0398  Tue Jan 23 2024 05:30:00 GMT+0530 (India Stand...
# 398  ORD-0399  Fri Nov 15 2024 05:30:00 GMT+0530 (India Stand...
# 399  ORD-0400  Wed Jul 03 2024 05:30:00 GMT+0530 (India Stand...
#
#     Customer Name Product Name         Category   Region       State  \
# 395  James Wilson         Desk        Furniture    South       Texas
# 396  James Wilson    Bookshelf        Furniture     West    Illinois
# 397    John Smith    Bookshelf        Furniture     West  California
# 398  Robert Brown        Paper  Office Supplies     West    Illinois
# 399   Linda Davis        Paper  Office Supplies  Central  California
#
#      Quantity   Sales  Discount  Profit
# 395         9  2700.0      0.15  183.96
# 396         7  1260.0      0.20  232.15
# ...

# %%
store.isna()
# Out:
#      Order ID  Order Date  Customer Name  Product Name  Category  Region  \
# 0       False       False          False         False     False   False
# 1       False       False          False         False     False   False
# 2       False       False          False         False     False   False
# 3       False       False          False         False     False   False
# 4       False       False          False         False     False   False
# ..        ...         ...            ...           ...       ...     ...
# 395     False       False          False         False     False   False
# 396     False       False          False         False     False   False
# 397     False       False          False         False     False   False
# 398     False       False          False         False     False   False
# 399     False       False          False         False     False   False
#
#      State  Quantity  Sales  Discount  Profit
# ...

# %%
store.describe()
# Out:
#          Quantity        Sales    Discount       Profit
# count  400.000000   400.000000  400.000000   400.000000
# mean     5.652500  1298.382500    0.104125   214.357925
# std      2.870949  1881.413271    0.070368   332.705005
# min      1.000000     6.000000    0.000000     1.070000
# 25%      3.000000    72.000000    0.050000    11.897500
# 50%      6.000000   520.000000    0.100000    86.395000
# 75%      8.000000  1760.000000    0.150000   289.417500
# max     10.000000  8500.000000    0.200000  2065.640000
